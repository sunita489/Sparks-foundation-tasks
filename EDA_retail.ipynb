# %% [markdown]
# **Exploratory Data Analysis (EDA) on Superstore dataset to derive
# important insights.**
#
# By Vaishnavi Ajit Mankapure

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
eda_df = pd.read_csv('SampleSuperstore.csv')
eda_df.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
eda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
eda_df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
eda_df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(eda_df.corr() , annot=True , cbar=True)

# %%
eda_df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
eda_df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ***Exploratory Data Analysis***
#
# Distribution Plot

# %%
fig , axs = plt.subplots(ncols = 2 , nrows = 2 , figsize = (10,10))
sns.distplot(eda_df['Sales'], color = 'blue', ax = axs[0][0])
sns.distplot(eda_df['Profit'], color = 'red', ax = axs[0][1])
sns.distplot(eda_df['Quantity'], color = 'green', ax = axs[1][0])
sns.distplot(eda_df['Discount'], color = 'orange', ax = axs[1][1])

axs[0][0].set_title('Sales distribution' , fontsize = 20)
axs[0][1].set_title('Profit distribution' , fontsize = 20)
axs[1][0].set_title('Quantity distribution' , fontsize = 20)
axs[1][1].set_title('Discount distribution' , fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(eda_df['Sales'],color='red',label='Sales',shade=True,bw=25)
sns.kdeplot(eda_df['Profit'],color='green',label='Profit',shade=True,bw=25)
plt.xlim([-100,1000])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ***Pairplot to analyse each column***
#
# 1.Based on Category

# %%
sns.pairplot(eda_df , hue = 'Category')

# %% [markdown]
# 2.Based on Region

# %%
sns.pairplot(eda_df , hue = 'Region')

# %% [markdown]
# 3. Based on Segment

# %%
#Pairplot to analyse each column
#1. Based on Segment
sns.pairplot(eda_df , hue = 'Segment')

# %% [markdown]
# ***Analyzing Profit based on various aspects***
#
# 1.Based on Ship Mode

# %%
eda_df['Ship Mode'].unique()
eda_df['Ship Mode'].value_counts()
sns.countplot(eda_df['Ship Mode'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_shipmode = eda_df.groupby(['Ship Mode'])['Sales','Discount','Profit'].mean()
df_shipmode
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      Sales  Discount     Profit
# Ship Mode
# First Class     228.497024  0.164610  31.839948
# Same Day        236.396179  0.152394  29.266591
# Second Class    236.089239  0.138895  29.535545
# Standard Class  227.583067  0.160023  27.494770

# %%
eda_df[eda_df['Ship Mode']=='Standard Class'].Profit.sum()
# Out:
# 164088.7875

# %%
eda_df[eda_df['Ship Mode']== 'First Class'].Profit.sum()
# Out:
# 48969.8399

# %%
eda_df[eda_df['Ship Mode']== 'Second Class'].Profit.sum()
# Out:
# 57446.63540000001

# %%
eda_df[eda_df['Ship Mode']== 'Same day'].Profit.sum()
# Out:
# 0.0

# %%
df_shipmode.plot.pie(subplots = True,labels = df_shipmode.index,autopct = '%1.2f%%',figsize = (18,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3327fccd50>,
# ...
#       dtype=object)

# %% [markdown]
# Profit is more in first class
#
# Discount is more in First class
#
# Sales are more in same day
#
# ***Analyzing Profit Based on Segments***

# %%
eda_df['Segment'].unique()
eda_df['Segment'].value_counts()
sns.countplot(eda_df['Segment'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
eda_df[eda_df['Segment'] == 'Consumer'].Profit.sum()
# Out:
# 134119.2092

# %%
eda_df[eda_df['Segment'] == 'Corporate'].Profit.sum()
# Out:
# 91979.13399999999

# %%
eda_df[eda_df['Segment'] == 'Home Office'].Profit.sum()
# Out:
# 60298.678499999995

# %%
eda_df[eda_df['Segment']=='Consumer'].Profit.sum()/len(eda_df[eda_df['Segment']=='Consumer'])
# Out:
# 25.8368732806781

# %%
df_segment = eda_df.groupby('Segment')[['Sales','Discount','Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
df_segment.plot.pie(subplots = True, labels = df_segment.index,figsize = (18,20),autopct = '%1.2f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3327e67450>,
# ...
#       dtype=object)

# %% [markdown]
# Sales and Profit both are more in Home Office segment.
#
# Discount is more in corporate.
#
# ***Profit analyzation based on city***

# %%
eda_df['City'].unique()
eda_df['City'].value_counts
fig ,ax = plt.subplots(figsize = (30,8))
sns.countplot(eda_df['City'].head(100),ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
eda_df_city = eda_df.groupby('City')[['Sales','Discount','Profit']].mean()
eda_df_city.head(10)
# Out:
#                   Sales  Discount     Profit
# City
# Aberdeen      25.500000  0.000000   6.630000
# Abilene        1.392000  0.800000  -3.758400
# Akron        129.999333  0.357143  -8.887410
# Albuquerque  158.582857  0.057143  45.292007
# Alexandria   344.973125  0.000000  19.913644
# Allen         72.551500  0.375000  -9.969375
# Allentown    121.893143  0.271429 -32.350057
# Altoona       10.225500  0.450000  -0.591750
# Amarillo     377.306280  0.272000 -38.796830
# Anaheim      295.810000  0.081481  45.703837

# %%
eda_df_city.tail(10)
# Out:
#                  Sales  Discount      Profit
# City
# Wilmington  202.696139  0.080556   54.102831
# Wilson       61.455333  0.366667   -2.389333
# Woodbury    202.550000  0.000000   65.365400
# Woodland     88.220667  0.133333   11.128267
# Woodstock   228.780000  0.260000   15.998580
# Woonsocket   48.887500  0.000000   19.669775
# Yonkers     510.511067  0.066667  184.517047
# York        163.595600  0.420000  -20.433840
# Yucaipa      50.800000  0.000000   13.208000
# Yuma        210.216250  0.450000 -116.497725

# %%
#Sorting the cities with respect to profit in descending
eda_df_city = eda_df_city.sort_values('Profit',ascending = False)
#Top ten 10 Profit giving cities
eda_df_city.head(10)
# Out:
#                     Sales  Discount      Profit
# City
# Jamestown     2354.395000  0.000000  642.885750
# Independence  1208.685000  0.000000  487.831500
# Lafayette      807.619355  0.000000  323.173794
# Minneapolis    733.501739  0.000000  296.721070
# Appleton       835.655000  0.000000  277.383150
# Morristown     719.014286  0.000000  262.603871
# Burbank       1082.386000  0.066667  254.844600
# Lehi           758.363000  0.100000  225.831300
# Beverly        861.063333  0.000000  218.306467
# Warwick        485.368000  0.000000  212.759120

# %%
#Plot Profit,Discount ,sale of Top 30 cities
eda_df_city.head(30).plot(kind = 'bar',color = 'red',figsize= (18,20))
eda_df_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color = 'Green')
plt.title('City wise analysis of  profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of  profit')

# %%
#Low Profit
eda_df_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color = 'yellow')
plt.title('City wise analysis of profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of profit')

# %% [markdown]
# ***State wise analysis of Profit , Sales ,Discount***
#
# State wise analysis of Profit

# %%
eda_df['State'].value_counts
eda_df['State'].unique()
eda_df_state = eda_df.groupby('State')['Sales','Discount','Profit'].mean()
eda_df_state.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """
#                  Sales  Discount     Profit
# State
# Alabama     319.846557  0.000000  94.865989
# Arizona     157.508933  0.303571 -15.303235
# Arkansas    194.635500  0.000000  66.811452
# California  228.729451  0.072764  38.171608
# Colorado    176.418231  0.316484 -35.867351

# %%
eda_df_state.sort_values('Profit',ascending = False,inplace = True)
eda_df_state.head(10)
# Out:
#                             Sales  Discount      Profit
# State
# Vermont                811.760909  0.000000  204.088936
# Rhode Island           404.070643  0.021429  130.100523
# Indiana                359.431946  0.000000  123.375411
# Montana                372.623467  0.066667  122.221900
# Minnesota              335.541011  0.000000  121.608847
# District of Columbia   286.502000  0.000000  105.958930
# Delaware               285.948635  0.006250  103.930988
# Wyoming               1603.136000  0.200000  100.196000
# Missouri               336.441667  0.000000   97.518341
# Michigan               299.096525  0.007059   95.934069

# %%
eda_df_state[['Profit']].plot(kind = 'bar',figsize = (20,8))
plt.xlabel('Profit ')
plt.ylabel('Name of States')
plt.title('Profit vs States')
plt.legend()

# %% [markdown]
# ***Highest Profit giving city is "Vermont ".***
#
# Lowest Profit giving city is "Ohio"
#
# State wise analysis of sales

# %%
eda_df_state[['Sales']].plot.pie(subplots = True,autopct = "%1.2f%%",figsize =(50,20),labels = eda_df_state.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3327593c90>],
#       dtype=object)

# %%
#Let plot graph of top h 30 ighest sales states
eda_df_state1 = eda_df_state.sort_values('Sales',ascending = False)
eda_df_state1[['Sales']].head(30).plot(kind = 'bar',color = 'orange',figsize = (20,8))
plt.xlabel('States',fontsize = 15)
plt.ylabel('Sales')
plt.title('Plot of Top 30 Sales State',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Plot of Top 30 Sales State')

# %% [markdown]
# Highest sale : Wyoming

# %%
#Highest sale : Wyoming
eda_df_state1[['Sales']].tail(30).plot(kind = 'bar',color = 'blue',figsize = (20,8))
plt.title('Plot of least Sales State',fontsize = 20)
plt.xlabel('States',fontsize =15)
plt.ylabel('Sales',fontsize = 15)
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ***Lowest sale : South Dakota***
#
# Discount analysis state wise

# %%
eda_df_state1['Discount'].plot(kind='bar',figsize=(20,5))
plt.title('State wise analysis of Discount', fontsize=20)
plt.xlabel('State',fontsize = 15)
plt.ylabel('Discount',fontsize = 15)
# Out:
# Text(0, 0.5, 'Discount')

# %% [markdown]
# Highest Discount is in Illinois State
#
# ***Category wise analysis of Profit***

# %%
eda_df['Category'].unique()
eda_df_category = eda_df.groupby('Category')[['Sales','Discount','Profit']].mean()
eda_df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
eda_df_category.plot.pie(subplots=True, 
                     figsize=(20, 20), 
                     autopct='%1.2f%%', 
                     labels = eda_df_category.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3326fdee50>,
# ...
#       dtype=object)

# %% [markdown]
# Highest Profit and Sales is in Technology
#
# Though Furniture has 37.95% of total Sale its profit is too less.
#
# As highest amount of discount is given in furniture .(17.39%)
#
# ***Subcategory wise Sales, Profit and Discount analysis***

# %%
eda_df_sub_category = eda_df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
eda_df_sub_category.head(10)

eda_df_sub_category[['Sales','Discount']].plot(kind = 'pie', autopct = '%1.2f%%',figsize = (30,20),
                                               labels = eda_df_sub_category.index,subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3326c2c950>,
# ...
#       dtype=object)

# %% [markdown]
# Maximum sale is in Copiers , Machines ,Chairs respectively.
#
# Minimum sale is in art.
#
# Maximum discount on Binders, Machines and Tables

# %%
eda_df_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',
                                                              figsize= (15,5),
                                                              label=['Average Sales Price','Profit'])

# %% [markdown]
# ***Profit analysis Region wise***

# %%
eda_df.Region.unique()
eda_df_region = eda_df.groupby('Region')['Sales','Profit','Discount'].mean()
eda_df_region.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#               Sales     Profit  Discount
# Region
# Central  215.772661  17.092709  0.240353
# East     238.336110  32.135808  0.145365
# South    241.803645  28.857673  0.147253
# West     226.493233  33.849032  0.109335

# %%
eda_df_region.plot(kind = 'pie',autopct = '%1.2f%%',subplots = True, figsize = (20,8),labels = eda_df_region.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3326ef2610>,
# ...
#       dtype=object)

# %% [markdown]
# **SUMMARY**
#
# Profit is more than sales .
#
# Furniture has less profit mainly beacause of huge discount on Tables .
#
# So need to think about discount on tables
#
# Quantity doesn't affect the profit , that means profit per item is not consistent.
#
# State Ohio : Lowest Profit
#
# State Vermont : Highest profit
#
# Out of Total profit , 73 % is from Technology .
#
# Sales and Profit are Moderately Correlated.
#
# Quantity and Profit are less Moderately Correlated.
#
# Discount and Profit are Negatively Correlated
#
# Lowest amount of sales= South Dakota(0.8%)
